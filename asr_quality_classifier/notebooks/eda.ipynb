# %% [markdown]
# # ASR Quality Classifier - Exploratory Data Analysis (EDA)
#
# ## Overview
# This notebook analyzes the ~4,000 audio-transcript pairs to understand:
# - Label distribution (usable vs not-usable)
# - Audio characteristics (duration, sample rate, quality)
# - Transcript characteristics (length, language patterns)
# - Data quality issues & edge cases
#
# ---

# %% [markdown]
# ## 1. Setup & Load Data

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import librosa

from src.config import Config
from src.data_loader import DataManager
from src.utils import setup_logger, set_random_seed

# Setup
set_random_seed(Config.RANDOM_SEED)
logger = setup_logger(__name__)

# Visualization
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')

print("✅ Setup complete")

# %% [markdown]
# ## 2. Load Labels & Data Summary

# %%
# Load data manager
data_manager = DataManager()

# Load labels
labels_df = data_manager.load_labels()
print(f"Loaded {len(labels_df)} labels")
print(labels_df.head())

# %% [markdown]
# ## 3. Label Distribution

# %%
# Print data statistics
data_manager.print_data_summary()

# Label counts
label_counts = labels_df['label'].value_counts().sort_index()
print("\nLabel Distribution:")
print(f"  0 (Not Usable): {label_counts.get(0, 0):>5} ({label_counts.get(0, 0)/len(labels_df)*100:.1f}%)")
print(f"  1 (Usable):     {label_counts.get(1, 0):>5} ({label_counts.get(1, 0)/len(labels_df)*100:.1f}%)")

# %% [markdown]
# ## 4. Audio Statistics

# %%
# TODO: Analyze audio files
# - Duration statistics
# - Sample rates
# - SNR estimates
# - Sample audio files

print("Audio analysis coming soon...")

# %% [markdown]
# ## 5. Transcript Statistics

# %%
# TODO: Analyze transcripts
# - Length distribution
# - Vocabulary statistics
# - Language patterns

print("Transcript analysis coming soon...")

# %% [markdown]
# ## 6. Sample Examples

# %%
# TODO: Display sample audio and transcripts
# - Sample from usable class
# - Sample from not-usable class

print("Sample examples coming soon...")

# %% [markdown]
# ## 7. Key Findings

# %%
print("""
Key Findings (Placeholder)
=========================

1. Class Balance:
   - [To be filled]

2. Audio Characteristics:
   - [To be filled]

3. Transcript Characteristics:
   - [To be filled]

4. Data Quality Issues:
   - [To be filled]

5. Recommendations:
   - [To be filled]
""")
